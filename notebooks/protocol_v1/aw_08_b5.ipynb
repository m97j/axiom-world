# %% [markdown]
# # aw_08_b5 — Stage B5: PlayWorld DPO from the B4 policy (Track B, §5.1)
#
# **Parent = B4** (`20260812-235057--b4-playworld-sft-from-p1--s42--72f4f6`,
# output sha256:378ba470...). Mirrors A2 exactly (same mining recipe, budget,
# DPO profile); the only difference is the parent line (base→B1v2→B4 vs base→A1).
# Primary readouts: B5 vs B4 (does DPO still help after two-stage SFT?) and
# B5 vs A2 (two-stage vs direct under the same DPO recipe).
#
# **x15 FAILED (2026-08-13, deviation D1)** — B4 is being retrained as B4v2 on the
# frozen A1-matched artifact (aw_07 §B4v2). This stage now starts from **B4v2**:
# set B4_RUN_ID below to the B4v2 run id once its eval/analysis is accepted.
#
# Cell order: x15 gate → fetch B4 → `a_b5_data` → `b_b5_train` → `c_b5_eval` →
# `x09g_run_audit` → `f_b5_analysis`.
#
#
# **v1.3 note:** x16 showed A1 also trained on an unfrozen build ⇒ remediation is a
# paired retrain (A1v2 + B4v2 on the pinned canonical artifact, aw_07). B5 parents on
# **B4v2**; the B5-vs-A2 comparison requires **A2v2** (re-mine + DPO from A1v2 under
# the A2 recipe) — do not compare B5 against v1 A2.
#
#
# **2026-08-14:** RQ1 closed (B4v2≫A1v2, 10/10 p=.0001). This stage now runs BOTH
# Phase-2 DPO arms in parallel under the identical recipe: **A2v2** (parent a1v2
# 269d0e) and **B5** (parent b4v2 c56ed2). Primary readouts: B5 vs B4v2 (DPO gain
# on two-stage), A2v2 vs A1v2 (DPO gain on direct), B5 vs A2v2 (two-stage vs
# direct after DPO — the Phase-2 headline).
#
#
# **STAGE RECORD (CLOSED 2026-08-14).** Mining: b4v2 1350 pairs (yield .675,
# no_passed 533) vs a1v2 893 (yield .447, no_passed 1107) — the two-stage parent
# leaves the miner far more usable signal. DPO runs a2v2 ef1e20 (margins .45,
# acc .85) / b5 4c45da (margins .07, acc .66 — weak gradient: parent already
# strong on its own rollouts). Evals 61d7cd / f77cd8, freeze 3cdcbc30, x09:
# b5 trunc/runaway 0.0; a2v2 trunc .993/runaway .91 (A-track pathology persists
# through DPO). Findings: (1) **B5 vs B4v2 ~null** — only sig cell adversarial
# pass −.037 (p=.047, isolated at α=.05 over 10 cells); DPO adds nothing after
# two-stage SFT under this recipe. (2) A2v2 vs A1v2: small sig mean_score gains
# (adv +.074, template +.044, comp +.026) but pass_rate gains n.s. except
# adversarial +.053 — DPO helps the weaker direct arm modestly. (3) **Phase-2
# headline: B5 ≫ A2v2 on all 10 cells (p≤.0002)** — the two-stage advantage
# survives identical DPO. §6 Phase-2 champion: B5-vs-B4v2 proxy tie → rule-OOD
# tie → GPU-hours → **champion = B4v2** (SFT). B6 (GRPO, aw_09) initializes
# from B4v2, yielding a clean online-RL vs offline-DPO comparison from one parent.

# %%
# @title common header
import os

from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')
os.environ["WANDB_API_KEY"] = userdata.get('WANDB_API_KEY')
os.environ["GITHUB_TOKEN"] = userdata.get('GITHUB_TOKEN')

# !git clone https://{os.environ["GITHUB_TOKEN"]}@github.com/m97j/axiom-world.git
# %cd axiom-world
# !pip install -e . -r requirements/colab-g4.lock.txt
# Out:
# Cloning into 'axiom-world'...
# remote: Enumerating objects: 636, done.
# remote: Counting objects: 100% (185/185), done.
# remote: Compressing objects: 100% (128/128), done.
# remote: Total 636 (delta 112), reused 106 (delta 46), pack-reused 451 (from 1)
# Receiving objects: 100% (636/636), 277.81 KiB | 9.58 MiB/s, done.
# Resolving deltas: 100% (344/344), done.
# /content/axiom-world
# Obtaining file:///content/axiom-world
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers==5.13.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 7)) (5.13.1)
# Requirement already satisfied: accelerate==1.14.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 8)) (1.14.0)
# Requirement already satisfied: peft==0.19.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 9)) (0.19.1)
# Requirement already satisfied: tokenizers==0.22.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 10)) (0.22.2)
# Requirement already satisfied: safetensors==0.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 11)) (0.8.0)
# Requirement already satisfied: huggingface_hub==1.23.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 12)) (1.23.0)
# Collecting trl==1.9.0 (from -r requirements/colab-g4.lock.txt (line 17))
#   Downloading trl-1.9.0-py3-none-any.whl.metadata (12 kB)
# Collecting datasets==5.0.0 (from -r requirements/colab-g4.lock.txt (line 21))
#   Downloading datasets-5.0.0-py3-none-any.whl.metadata (23 kB)
# Collecting torchao==0.17.0 (from -r requirements/colab-g4.lock.txt (line 22))
#   Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pydantic==2.13.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 25)) (2.13.4)
# Requirement already satisfied: PyYAML==6.0.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 26)) (6.0.3)
# Requirement already satisfied: orjson==3.11.9 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 27)) (3.11.9)
# Requirement already satisfied: wandb==0.28.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 28)) (0.28.0)
# Requirement already satisfied: psutil==5.9.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 29)) (5.9.5)
# Requirement already satisfied: rich==13.9.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 30)) (13.9.4)
# Requirement already satisfied: tqdm==4.67.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements/colab-g4.lock.txt (line 31)) (4.67.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==5.13.1->-r requirements/colab-g4.lock.txt (line 7)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==5.13.1->-r requirements/colab-g4.lock.txt (line 7)) (26.2)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers==5.13.1->-r requirements/colab-g4.lock.txt (line 7)) (2025.11.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers==5.13.1->-r requirements/colab-g4.lock.txt (line 7)) (0.26.8)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (2.11.0+cu128)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==1.23.0->-r requirements/colab-g4.lock.txt (line 12)) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==1.23.0->-r requirements/colab-g4.lock.txt (line 12)) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==1.23.0->-r requirements/colab-g4.lock.txt (line 12)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==1.23.0->-r requirements/colab-g4.lock.txt (line 12)) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==1.23.0->-r requirements/colab-g4.lock.txt (line 12)) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==1.23.0->-r requirements/colab-g4.lock.txt (line 12)) (4.16.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from trl==1.9.0->-r requirements/colab-g4.lock.txt (line 17)) (3.1.6)
# Collecting pyarrow>=21.0.0 (from datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21))
#   Downloading pyarrow-25.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (3.8.1)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (0.70.16)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic==2.13.4->-r requirements/colab-g4.lock.txt (line 25)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic==2.13.4->-r requirements/colab-g4.lock.txt (line 25)) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic==2.13.4->-r requirements/colab-g4.lock.txt (line 25)) (0.4.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.28.0->-r requirements/colab-g4.lock.txt (line 28)) (3.1.51)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb==0.28.0->-r requirements/colab-g4.lock.txt (line 28)) (4.10.0)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.28.0->-r requirements/colab-g4.lock.txt (line 28)) (5.29.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.28.0->-r requirements/colab-g4.lock.txt (line 28)) (2.65.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich==13.9.4->-r requirements/colab-g4.lock.txt (line 30)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich==13.9.4->-r requirements/colab-g4.lock.txt (line 30)) (2.20.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (3.14.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.28.0->-r requirements/colab-g4.lock.txt (line 28)) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub==1.23.0->-r requirements/colab-g4.lock.txt (line 12)) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub==1.23.0->-r requirements/colab-g4.lock.txt (line 12)) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub==1.23.0->-r requirements/colab-g4.lock.txt (line 12)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub==1.23.0->-r requirements/colab-g4.lock.txt (line 12)) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub==1.23.0->-r requirements/colab-g4.lock.txt (line 12)) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich==13.9.4->-r requirements/colab-g4.lock.txt (line 30)) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (2.5.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (3.6.1)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (12.8.90)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->trl==1.9.0->-r requirements/colab-g4.lock.txt (line 17)) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (2026.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers==5.13.1->-r requirements/colab-g4.lock.txt (line 7)) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers==5.13.1->-r requirements/colab-g4.lock.txt (line 7)) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (1.24.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (1.5.6)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.28.0->-r requirements/colab-g4.lock.txt (line 28)) (5.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==5.0.0->-r requirements/colab-g4.lock.txt (line 21)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate==1.14.0->-r requirements/colab-g4.lock.txt (line 8)) (1.3.0)
# Downloading trl-1.9.0-py3-none-any.whl (884 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 885.0/885.0 kB 39.7 MB/s eta 0:00:00
# Downloading datasets-5.0.0-py3-none-any.whl (555 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 72.5 MB/s eta 0:00:00
# Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 157.5 MB/s eta 0:00:00
# Downloading pyarrow-25.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (50.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 68.3 MB/s eta 0:00:00
# Building wheels for collected packages: axiom-world
#   Building editable for axiom-world (pyproject.toml) ... done
#   Created wheel for axiom-world: filename=axiom_world-0.6.10-0.editable-py3-none-any.whl size=2526 sha256=1919ef2faa766ec109856ca742d589530767ecb5cf61ba704e9e542d8282f932
#   Stored in directory: /tmp/pip-ephem-wheel-cache-crdtr78s/wheels/77/a5/e9/f220e2a512545f446037fa4e8af8c369a03e93b4917a90420f
# Successfully built axiom-world
# Installing collected packages: torchao, pyarrow, axiom-world, datasets, trl
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# Successfully installed axiom-world-0.6.10 datasets-5.0.0 pyarrow-25.0.1 torchao-0.17.0 trl-1.9.0

# %%
# @title x15 gate — RESULT: CONTENT DIVERGED (2026-08-13). Kept for the record;
# do NOT rerun. B5 proceeds from B4v2 (see aw_07 §B4v2).
# Frozen A1-era artifact vs the aw_07 rebuild. Adjust --path if the artifact
# lives elsewhere in m97j/aw-playworld.
# !python scripts/fetch_dataset.py \
  --repo m97j/aw-playworld \
  --path preference_train/v1/playworld_sft.jsonl \
  --output data/frozen/playworld_sft_a1era.jsonl

# !python scripts/build_training_data.py \
  --seed 1042 --scenarios-per-family 400 --output-dir data/train

# !python scripts/x15_sft_data_diff.py \
  --file-a data/frozen/playworld_sft_a1era.jsonl --label-a a1-era-frozen \
  --file-b data/train/playworld_sft.jsonl --label-b rebuild \
  --out runs/x15_sft_data_diff.json
# Out:
# playworld_sft.jsonl: 100% 3.48M/3.48M [00:00<00:00, 24.3MB/s]
# fetched dataset: hf://m97j/aw-playworld/preference_train/v1/playworld_sft.jsonl
# revision: main
# materialized: data/frozen/playworld_sft_a1era.jsonl
# dataset sha256: 260e15d62f85385461ed0c31b03626821bce95e46b3fde549412a811a07032ea
# DATASET_PATH=data/frozen/playworld_sft_a1era.jsonl
# DATASET_SHA256=260e15d62f85385461ed0c31b03626821bce95e46b3fde549412a811a07032ea
# {
#   "seed": 1042,
#   "sft_records": 2000,
#   "prompt_records": 2000,
#   "unsolvable_dropped": 0,
#   "sft_fingerprint": "sha256:87c9fb143d30c3dd5c0922553485e50895b958f3b0b9fa05bc970b0f4e2ef997",
#   "prompt_fingerprint": "sha256:cc2aef0df4f5efda3db7ccfd43c76e40260935e9b7b55ee5760490e6a4304f14",
#   "train_families": [
#     "train-fam0",
#     "train-fam1",
#     "train-fam2",
#     "train-fam3",
#     "train-fam4"
#   ],
#   "eval_families_checked": [
#     "eval_adversarial-fam0",
#     "eval_comp_ood-fam0",
#     "eval_comp_ood-fam1",
#     "eval_id-fam0",
#     "eval_id-fam1",
#     "eval_id-fam2",
#     "eval_rule_ood-fam0",
#     "eval_rule_ood-fam1",
#     "eval_template_ood-fam0",
#     "eval_template_ood-fam1"
#   ]
# }
# {
#   "file_a": {
#     "label": "a1-era-frozen",
#     "path": "data/frozen/playworld_sft_a1era.jsonl",
#     "records": 2000,
#     "canonical_set_sha256": "260e15d62f85385461ed0c31b03626821bce95e46b3fde549412a811a07032ea"
#   },
#   "file_b": {
#     "label": "rebuild",
#     "path": "data/train/playworld_sft.jsonl",
#     "records": 2000,
#     "canonical_set_sha256": "9b4474609b3a8bbbdbb7e876b064e6e91d5c3312462c7e28deb17d0763799048"
#   },
#   "order_identical": false,
#   "multiset_identical": false,
#   "records_only_in_a": 120,
#   "records_only_in_b": 120,
#   "sample_only_in_a": [
#     "{\"id\": \"sft-train-fam0-0022\", \"messages\": [{\"content\": \"You control an agent in a grid world.\\nWorld spec (JSON): {\\\"spec_id\\\":\\\"train-fam0-spec22\\\",\\\"family_id\\\":\\\"train-fam0\\\",\\\"rule_primitives\\\":[\\\"movement\\\",\\\"collection\\\",\\\"deposit\\\"],\\\"locations\\\":[\\\"loc_0\\\",\\\"loc_1\\\",\\\"loc_2\\\",\\\"loc_3\\\",\\\"loc_4\\\",\\\"loc_5\\\"],\\\"edges\\\":[[\\\"loc_0\\\",\\\"loc_1\\\"],[\\\"loc_1\\\",\\\"loc_2\\\"],[\\\"loc_2\\\",\\\"loc_3\\\"],[\\\"loc_",
#     "{\"id\": \"sft-train-fam0-0057\", \"messages\": [{\"content\": \"You control an agent in a grid world.\\nWorld spec (JSON): {\\\"spec_id\\\":\\\"train-fam0-spec57\\\",\\\"family_id\\\":\\\"train-fam0\\\",\\\"rule_primitives\\\":[\\\"movement\\\",\\\"collection\\\",\\\"deposit\\\"],\\\"locations\\\":[\\\"loc_0\\\",\\\"loc_1\\\",\\\"loc_2\\\",\\\"loc_3\\\",\\\"loc_4\\\",\\\"loc_5\\\"],\\\"edges\\\":[[\\\"loc_0\\\",\\\"loc_1\\\"],[\\\"loc_1\\\",\\\"loc_2\\\"],[\\\"loc_2\\\",\\\"loc_3\\\"],[\\\"loc_",
#     "{\"id\": \"sft-train-fam0-0066\", \"messages\": [{\"content\": \"You control an agent in a grid world.\\nWorld spec (JSON): {\\\"spec_id\\\":\\\"train-fam0-spec66\\\",\\\"family_id\\\":\\\"train-fam0\\\",\\\"rule_primitives\\\":[\\\"movement\\\",\\\"collection\\\",\\\"deposit\\\"],\\\"locations\\\":[\\\"loc_0\\\",\\\"loc_1\\\",\\\"loc_2\\\",\\\"loc_3\\\",\\\"loc_4\\\",\\\"loc_5\\\"],\\\"edges\\\":[[\\\"loc_0\\\",\\\"loc_1\\\"],[\\\"loc_1\\\",\\\"loc_2\\\"],[\\\"loc_2\\\",\\\"loc_3\\\"],[\\\"loc_"
#   ],
#   "sample_only_in_b": [
#     "{\"id\": \"sft-train-fam0-0022\", \"messages\": [{\"content\": \"You control an agent in a grid world.\\nWorld spec (JSON): {\\\"spec_id\\\":\\\"train-fam0-spec22\\\",\\\"family_id\\\":\\\"train-fam0\\\",\\\"rule_primitives\\\":[\\\"movement\\\",\\\"collection\\\",\\\"deposit\\\"],\\\"locations\\\":[\\\"loc_0\\\",\\\"loc_1\\\",\\\"loc_2\\\",\\\"loc_3\\\",\\\"loc_4\\\",\\\"loc_5\\\"],\\\"edges\\\":[[\\\"loc_0\\\",\\\"loc_1\\\"],[\\\"loc_1\\\",\\\"loc_2\\\"],[\\\"loc_2\\\",\\\"loc_3\\\"],[\\\"loc_",
#     "{\"id\": \"sft-train-fam0-0057\", \"messages\": [{\"content\": \"You control an agent in a grid world.\\nWorld spec (JSON): {\\\"spec_id\\\":\\\"train-fam0-spec57\\\",\\\"family_id\\\":\\\"train-fam0\\\",\\\"rule_primitives\\\":[\\\"movement\\\",\\\"collection\\\",\\\"deposit\\\"],\\\"locations\\\":[\\\"loc_0\\\",\\\"loc_1\\\",\\\"loc_2\\\",\\\"loc_3\\\",\\\"loc_4\\\",\\\"loc_5\\\"],\\\"edges\\\":[[\\\"loc_0\\\",\\\"loc_1\\\"],[\\\"loc_1\\\",\\\"loc_2\\\"],[\\\"loc_2\\\",\\\"loc_3\\\"],[\\\"loc_",
#     "{\"id\": \"sft-train-fam0-0066\", \"messages\": [{\"content\": \"You control an agent in a grid world.\\nWorld spec (JSON): {\\\"spec_id\\\":\\\"train-fam0-spec66\\\",\\\"family_id\\\":\\\"train-fam0\\\",\\\"rule_primitives\\\":[\\\"movement\\\",\\\"collection\\\",\\\"deposit\\\"],\\\"locations\\\":[\\\"loc_0\\\",\\\"loc_1\\\",\\\"loc_2\\\",\\\"loc_3\\\",\\\"loc_4\\\",\\\"loc_5\\\"],\\\"edges\\\":[[\\\"loc_0\\\",\\\"loc_1\\\"],[\\\"loc_1\\\",\\\"loc_2\\\"],[\\\"loc_2\\\",\\\"loc_3\\\"],[\\\"loc_"
#   ],
#   "verdict": "CONTENT DIVERGED — B4 trained on different data than A1; the RQ1 comparison is confounded. Retrain B4 from the frozen A1-era artifact before proceeding to B5/B6."
# }

# %%
# @title fetch parents — B4v2 (treatment) + A1v2 (control)
B4V2_RUN_ID = "20260814-023603--b4v2-playworld-sft-from-p1--s42--c56ed2"
A1V2_RUN_ID = "20260814-022256--a1v2-playworld-sft--s42--269d0e"

out = !python scripts/fetch_run.py --repo m97j/aw-runs-b4 --run-id {B4V2_RUN_ID}
b4v2_dir = [l for l in out if l.startswith("ADAPTER_DIR=")][0].split("=", 1)[1]
out = !python scripts/fetch_run.py --repo m97j/aw-runs-a1 --run-id {A1V2_RUN_ID}
a1v2_dir = [l for l in out if l.startswith("ADAPTER_DIR=")][0].split("=", 1)[1]

import json
b4v2_sha = json.load(open(f"runs/{B4V2_RUN_ID}/artifacts/lineage.json"))["output_adapter_sha256"]
a1v2_sha = json.load(open(f"runs/{A1V2_RUN_ID}/artifacts/lineage.json"))["output_adapter_sha256"]
print(b4v2_dir, b4v2_sha); print(a1v2_dir, a1v2_sha)
# Out:
# runs/20260814-023603--b4v2-playworld-sft-from-p1--s42--c56ed2/artifacts/final_adapter sha256:d4fcacddf21f758cdab904845ebdfee1eefde309c0edb6205bac64d5f07c76c8
# runs/20260814-022256--a1v2-playworld-sft--s42--269d0e/artifacts/final_adapter sha256:70c2ecb92b63da68b22c82ffac3325be0b67684518dd9b17bb1e1fa436508936

# %%
# @title a_b5_data — mine pairs from BOTH parents (identical recipe, GPU)
# Prompts: canonical frozen prompt stream (prompt_fingerprint cc2aef0d is stable,
# but fetch the frozen copy anyway per the v1.3 rule).
# !python scripts/fetch_dataset.py \
  --repo m97j/aw-playworld --path train/v1/playworld_prompts.jsonl \
  --output data/train/playworld_prompts.jsonl --force
# !python scripts/build_eval_suites.py --episodes-per-suite 300

for label, adp in (("b4", b4v2_dir), ("a1", a1v2_dir)):
    # !python scripts/mine_playworld_pairs.py \
      --config configs/experiments/eval_playworld.yaml \
      --adapter-dir {adp} \
      --prompt-file data/train/playworld_prompts.jsonl \
      --num-candidates 8 --temperature 0.8 --batch-size 100 \
      --selection-method hybrid_verifier_rank --minimum-margin 0.10 \
      --output data/train/playworld_preference_{label}.jsonl \
      --hf-sync-repo m97j/aw-playworld --hf-path-in-repo preference_train/{label}v2-v1
# Out:
# playworld_prompts.jsonl: 100% 4.60M/4.60M [00:00<00:00, 20.6MB/s]
# fetched dataset: hf://m97j/aw-playworld/train/v1/playworld_prompts.jsonl
# revision: main
# materialized: data/train/playworld_prompts.jsonl
# dataset sha256: 2e7d02603c47784328ee82bba8abb6ed8b9e32175567b72b7a68969a0ae361e6
# DATASET_PATH=data/train/playworld_prompts.jsonl
# DATASET_SHA256=2e7d02603c47784328ee82bba8abb6ed8b9e32175567b72b7a68969a0ae361e6
# eval_id: 300 episodes -> data/eval_suites/eval_id.jsonl (sha256:aceeea727d2b9eaed...)
# eval_template_ood: 300 episodes -> data/eval_suites/eval_template_ood.jsonl (sha256:13580a6cbf7a4e566...)
# eval_comp_ood: 300 episodes -> data/eval_suites/eval_comp_ood.jsonl (sha256:444191a244dcd77d1...)
# eval_rule_ood: 300 episodes -> data/eval_suites/eval_rule_ood.jsonl (sha256:d73745108f5e7e207...)
# eval_adversarial: 300 episodes -> data/eval_suites/eval_adversarial.jsonl (sha256:c73dd155acd069292...)
#
# G3 freeze manifest -> data/eval_suites/freeze_manifest.json
# Commit this manifest; training loaders must pass eval_family_ids as forbidden_family_ids (leakage gate).
# config.json: 100% 729/729 [00:00<00:00, 8.18MB/s]
# tokenizer_config.json: 100% 9.68k/9.68k [00:00<00:00, 8.08MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 62.9MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 280MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 319MB/s]
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 32.9k/32.9k [00:00<00:00, 166MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 5 files:   0% 0/5 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/7.95G [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/11.9G [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/16.4G [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/16.4G [00:00<?, ?B/s]
# Downloading bytes:   2% 394M/16.4G [00:01<00:18, 856MB/s, 7.38MB/s  ]
# Downloading bytes:   3% 546M/16.4G [00:01<00:15, 1.02GB/s, 10.4MB/s  ]
# Downloading bytes:   7% 1.13G/16.4G [00:01<00:11, 1.28GB/s, 18.7MB/s  ]
# Downloading bytes:  10% 1.65G/16.4G [00:02<00:09, 1.60GB/s, 24.4MB/s  ]
# Reconstructing (incomplete total...):   3% 428M/16.4G [00:02<00:54, 292MB/s, 9.65MB/s  ]
# Downloading bytes:  16% 2.61G/16.4G [00:02<00:07, 1.81GB/s, 52.8MB/s  ]
# Downloading bytes:  17% 2.81G/16.4G [00:02<00:07, 1.84GB/s, 52.2MB/s  ]
# Downloading bytes:  20% 3.21G/16.4G [00:02<00:07, 1.80GB/s, 50.6MB/s  ]
# Downloading bytes:  21% 3.42G/16.4G [00:03<00:06, 1.88GB/s, 53.7MB/s  ]
# Downloading bytes:  27% 4.44G/16.4G [00:03<00:06, 1.91GB/s, 67.3MB/s  ]
# Downloading bytes:  28% 4.64G/16.4G [00:03<00:06, 1.92GB/s, 69.0MB/s  ]
# Downloading bytes:  30% 4.86G/16.4G [00:03<00:07, 1.57GB/s, 88.9MB/s  ]
# Downloading bytes:  37% 6.10G/16.4G [00:04<00:07, 1.47GB/s, 91.6MB/s  ]
# Downloading bytes:  39% 6.40G/16.4G [00:05<00:20, 499MB/s, 91.0MB/s  ]
# Downloading bytes:  41% 6.77G/16.4G [00:07<00:46, 207MB/s,  100MB/s  ]
# Downloading bytes:  46% 7.61G/16.4G [00:11<01:07, 129MB/s, 75.6MB/s  ]
# Reconstructing (incomplete total...):  27% 4.35G/16.4G [00:12<00:59, 202MB/s, 48.7MB/s  ]
# Downloading bytes:  47% 7.77G/16.4G [00:14<01:59, 72.0MB/s, 74.0MB/s  ]
# Downloading bytes:  53% 8.74G/16.4G [00:17<00:38, 201MB/s, 75.0MB/s  ]
# Reconstructing (incomplete total...):  37% 6.13G/16.4G [00:17<00:33, 307MB/s, 88.2MB/s  ]
# Downloading bytes:  57% 9.37G/16.4G [00:17<00:08, 854MB/s, 74.7MB/s  ]
# Downloading bytes:  66% 10.8G/16.4G [00:21<00:41, 136MB/s, 88.5MB/s  ]
# Downloading bytes:  69% 11.2G/16.4G [00:23<00:20, 255MB/s, 74.8MB/s  ]
# Downloading bytes:  72% 11.7G/16.4G [00:25<00:33, 138MB/s, 74.5MB/s  ]
# Downloading bytes:  75% 12.3G/16.4G [00:26<00:07, 515MB/s, 66.6MB/s  ]
# Downloading bytes:  76% 12.5G/16.4G [00:27<00:08, 463MB/s, 68.7MB/s  ]
# Downloading bytes:  81% 13.3G/16.4G [00:29<00:14, 206MB/s, 71.6MB/s  ]
# Downloading bytes:  82% 13.4G/16.4G [00:30<00:23, 130MB/s, 97.1MB/s  ]
# Downloading bytes:  86% 14.0G/16.4G [00:31<00:02, 964MB/s, 98.8MB/s  ]
# Reconstructing (incomplete total...):  78% 12.8G/16.4G [00:34<00:12, 281MB/s, 99.4MB/s  ]
# Downloading bytes:  87% 14.3G/16.4G [00:35<00:15, 136MB/s, 73.4MB/s  ]
# Reconstructing (incomplete total...):  86% 14.1G/16.4G [00:39<00:09, 248MB/s, 94.8MB/s  ]
# Reconstructing (incomplete total...):  93% 15.3G/16.4G [00:39<00:02, 423MB/s,  110MB/s  ]
# Reconstructing (incomplete total...):  98% 16.0G/16.4G [00:40<00:00, 514MB/s,  119MB/s  ]
#
# Fetching 5 files:  20% 1/5 [00:40<02:41, 40.41s/it]
# Reconstructing (incomplete total...): 100% 16.4G/16.4G [00:41<00:00, 522MB/s,  115MB/s  ]
#
# Fetching 5 files: 100% 5/5 [00:41<00:00,  8.22s/it]
# Download complete: 100% 14.3G/14.3G [00:41<00:00, 136MB/s, 72.8MB/s  ]
# Download complete: 100% 14.3G/14.3G [00:41<00:00, 346MB/s, 72.8MB/s  ]
# Reconstruction complete: 100% 16.4G/16.4G [00:41<00:00, 396MB/s,  135MB/s  ]
# Loading weights: 100% 399/399 [00:01<00:00, 336.35it/s]
# generation_config.json: 100% 138/138 [00:00<00:00, 1.69MB/s]
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py:1348: UserWarning: Model has `tie_word_embeddings=True` and a tied layer is part of the adapter, but `ensure_weight_tying` is not set to True. This can lead to complications, for example when merging the adapter or converting your model to formats other than safetensors. Check the discussion here: https://github.com/huggingface/peft/issues/2777
#   warnings.warn(msg)
# mine(batched): 100% 167/167 [40:29<00:00, 14.55s/it]
# {
#   "adapter_dir": "runs/20260814-023603--b4v2-playworld-sft-from-p1--s42--c56ed2/artifacts/final_adapter",
#   "decision_counts": {
#     "accepted": 1350,
#     "identical_texts": 102,
#     "insufficient_candidates": 0,
#     "insufficient_margin": 15,
#     "no_passed_candidate": 533
#   },
#   "minimum_margin": 0.1,
#   "num_candidates": 8,
#   "opener_seed": "<think>\n\n</think>\n\n",
#   "pairs_accepted": 1350,
#   "preference_fingerprint": "sha256:67563932ff7460fd85704beaea5c564674ecee3f86c2c47ac8de63cdeed21a8b",
#   "prompt_file": "data/train/playworld_prompts.jsonl",
#   "prompts_processed": 2000,
#   "seed": 42,
#   "selection_method": "hybrid_verifier_rank",
#   "temperature": 0.8,
#   "top_p": 0.95
# }
# Found 5 files to upload
#   Preparing   ████████████████████  5 / 5 ✓
#   Uploading   ████████████████████  -
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 5
#   Preparing   ████████████████████  5 / 5 ✓
#   Uploading   ████████████████████  -
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 5
#   Preparing   ████████████████████  5 / 5 ✓
#   Uploading   ████████████████████  -
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 5
#   Preparing   ████████████████████  5 / 5 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████████████████  5 / 5 ✓
# preference data synced -> hf://dataset/m97j/aw-playworld/preference_train/b4v2-v1
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Loading weights: 100% 399/399 [00:01<00:00, 338.31it/s]
# mine(batched): 100% 167/167 [2:25:04<00:00, 52.12s/it]
# {
#   "adapter_dir": "runs/20260814-022256--a1v2-playworld-sft--s42--269d0e/artifacts/final_adapter",
#   "decision_counts": {
#     "accepted": 893,
#     "identical_texts": 0,
#     "insufficient_candidates": 0,
#     "insufficient_margin": 0,
#     "no_passed_candidate": 1107
#   },
#   "minimum_margin": 0.1,
#   "num_candidates": 8,
#   "opener_seed": "<think>\n\n</think>\n\n",
#   "pairs_accepted": 893,
#   "preference_fingerprint": "sha256:5856b5c5e2fc8fa9b20d1611431c13197ebbf780937020e73cf41064424167a9",
#   "prompt_file": "data/train/playworld_prompts.jsonl",
#   "prompts_processed": 2000,
#   "seed": 42,
#   "selection_method": "hybrid_verifier_rank",
#   "temperature": 0.8,
#   "top_p": 0.95
# }
# Found 6 files to upload
#   Preparing   ████████████████████  6 / 6 ✓
#   Uploading   ████████████████████  -
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 6
#   Preparing   ████████████████████  6 / 6 ✓
#   Uploading   ████████████████████  -
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 6
#   Preparing   ████████████████████  6 / 6 ✓
#   Uploading   ████████████████████  -
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 6
#   Preparing   ████████████████████  6 / 6 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████████████████  6 / 6 ✓
# preference data synced -> hf://dataset/m97j/aw-playworld/preference_train/a1v2-v1

# %%
# @title b_train — A2v2 then B5 (same DPO recipe, lineage-verified)
# !python scripts/run_experiment.py \
  --config configs/experiments/a2_playworld_dpo.yaml \
  --parent-adapter-dir {a1v2_dir} \
  --override lineage.parent_run_id={A1V2_RUN_ID} \
  --override lineage.parent_adapter.sha256={a1v2_sha} \
  --override experiment_name=a2v2-playworld-dpo \
  --override data.source.local_path=data/train/playworld_preference_a1.jsonl \
  --hf-sync-repo m97j/aw-runs-a2

# !python scripts/run_experiment.py \
  --config configs/experiments/b5_playworld_dpo.yaml \
  --parent-adapter-dir {b4v2_dir} \
  --override lineage.parent_run_id={B4V2_RUN_ID} \
  --override lineage.parent_adapter.sha256={b4v2_sha} \
  --override data.source.local_path=data/train/playworld_preference_b4.jsonl \
  --hf-sync-repo m97j/aw-runs-b5
# Out:
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# run_id: 20260814-114257--a2v2-playworld-dpo--s42--ef1e20
# Loading weights: 100% 399/399 [00:01<00:00, 341.59it/s]
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Adding EOS to train dataset: 100% 893/893 [00:00<00:00, 44668.15 examples/s]
# Tokenizing train dataset: 100% 893/893 [00:01<00:00, 535.54 examples/s]
# Dropping fully truncated examples from train dataset: 100% 893/893 [00:00<00:00, 29879.97 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: mmnkjiae (mmnkjiae-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.28.0
# wandb: Run data is saved locally in /content/axiom-world/wandb/run-20260814_114305-4pr7tjvr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run a2v2-playworld-dpo
# wandb: ⭐️ View project at https://wandb.ai/mmnkjiae-/axiom-world
# wandb: 🚀 View run at https://wandb.ai/mmnkjiae-/axiom-world/runs/4pr7tjvr
# {'loss': '0.6808', 'grad_norm': '12.31', 'learning_rate': '4.769e-07', 'entropy': '0.2403', 'num_tokens': '1.284e+05', 'logits/chosen': '2.484', 'logits/rejected': '4.478', 'mean_token_accuracy': '0.9574', 'rewards/chosen': '0.01677', 'rewards/rejected': '-0.0103', 'rewards/accuracies': '0.5375', 'rewards/margins': '0.02706', 'logps/chosen': '-128.6', 'logps/rejected': '-148.3', 'epoch': '0.08959'}
# {'loss': '0.6444', 'grad_norm': '10.47', 'learning_rate': '4.306e-07', 'entropy': '0.2012', 'num_tokens': '2.574e+05', 'logits/chosen': '2.461', 'logits/rejected': '4.243', 'mean_token_accuracy': '0.9655', 'rewards/chosen': '0.08035', 'rewards/rejected': '-0.02816', 'rewards/accuracies': '0.7375', 'rewards/margins': '0.1085', 'logps/chosen': '-115.5', 'logps/rejected': '-136.9', 'epoch': '0.1792'}
# {'loss': '0.611', 'grad_norm': '12.54', 'learning_rate': '3.843e-07', 'entropy': '0.2217', 'num_tokens': '3.862e+05', 'logits/chosen': '1.552', 'logits/rejected': '4.116', 'mean_token_accuracy': '0.9626', 'rewards/chosen': '0.1108', 'rewards/rejected': '-0.07937', 'rewards/accuracies': '0.8', 'rewards/margins': '0.1902', 'logps/chosen': '-125.4', 'logps/rejected': '-140.6', 'epoch': '0.2688'}
# {'loss': '0.5904', 'grad_norm': '16.84', 'learning_rate': '3.38e-07', 'entropy': '0.2186', 'num_tokens': '5.139e+05', 'logits/chosen': '2.284', 'logits/rejected': '4.41', 'mean_token_accuracy': '0.9604', 'rewards/chosen': '0.1062', 'rewards/rejected': '-0.1448', 'rewards/accuracies': '0.85', 'rewards/margins': '0.251', 'logps/chosen': '-120.3', 'logps/rejected': '-142.9', 'epoch': '0.3583'}
# {'loss': '0.5346', 'grad_norm': '8.669', 'learning_rate': '2.917e-07', 'entropy': '0.1924', 'num_tokens': '6.423e+05', 'logits/chosen': '1.882', 'logits/rejected': '4.331', 'mean_token_accuracy': '0.9668', 'rewards/chosen': '0.1668', 'rewards/rejected': '-0.2602', 'rewards/accuracies': '0.8375', 'rewards/margins': '0.427', 'logps/chosen': '-113.4', 'logps/rejected': '-135.9', 'epoch': '0.4479'}
# {'loss': '0.5459', 'grad_norm': '10.48', 'learning_rate': '2.454e-07', 'entropy': '0.2079', 'num_tokens': '7.707e+05', 'logits/chosen': '1.503', 'logits/rejected': '4.051', 'mean_token_accuracy': '0.9648', 'rewards/chosen': '0.1539', 'rewards/rejected': '-0.2273', 'rewards/accuracies': '0.8875', 'rewards/margins': '0.3812', 'logps/chosen': '-114.7', 'logps/rejected': '-143.1', 'epoch': '0.5375'}
# {'loss': '0.5452', 'grad_norm': '11.1', 'learning_rate': '1.991e-07', 'entropy': '0.2155', 'num_tokens': '8.99e+05', 'logits/chosen': '0.849', 'logits/rejected': '4.157', 'mean_token_accuracy': '0.9714', 'rewards/chosen': '0.2071', 'rewards/rejected': '-0.2016', 'rewards/accuracies': '0.85', 'rewards/margins': '0.4087', 'logps/chosen': '-105.5', 'logps/rejected': '-151.1', 'epoch': '0.6271'}
# {'loss': '0.5094', 'grad_norm': '9.499', 'learning_rate': '1.528e-07', 'entropy': '0.224', 'num_tokens': '1.027e+06', 'logits/chosen': '1.075', 'logits/rejected': '4.148', 'mean_token_accuracy': '0.9589', 'rewards/chosen': '0.2278', 'rewards/rejected': '-0.2912', 'rewards/accuracies': '0.9125', 'rewards/margins': '0.519', 'logps/chosen': '-123.1', 'logps/rejected': '-147.5', 'epoch': '0.7167'}
# {'loss': '0.5311', 'grad_norm': '12.59', 'learning_rate': '1.065e-07', 'entropy': '0.2328', 'num_tokens': '1.155e+06', 'logits/chosen': '2.037', 'logits/rejected': '3.796', 'mean_token_accuracy': '0.9605', 'rewards/chosen': '0.2442', 'rewards/rejected': '-0.2291', 'rewards/accuracies': '0.8625', 'rewards/margins': '0.4733', 'logps/chosen': '-125.1', 'logps/rejected': '-143.2', 'epoch': '0.8063'}
# {'loss': '0.5114', 'grad_norm': '10.69', 'learning_rate': '6.019e-08', 'entropy': '0.2097', 'num_tokens': '1.284e+06', 'logits/chosen': '2.489', 'logits/rejected': '4.195', 'mean_token_accuracy': '0.965', 'rewards/chosen': '0.1952', 'rewards/rejected': '-0.3574', 'rewards/accuracies': '0.775', 'rewards/margins': '0.5525', 'logps/chosen': '-111.2', 'logps/rejected': '-148.5', 'epoch': '0.8959'}
# {'loss': '0.5089', 'grad_norm': '8.73', 'learning_rate': '1.389e-08', 'entropy': '0.2083', 'num_tokens': '1.411e+06', 'logits/chosen': '1.209', 'logits/rejected': '3.2', 'mean_token_accuracy': '0.9686', 'rewards/chosen': '0.2282', 'rewards/rejected': '-0.3126', 'rewards/accuracies': '0.9', 'rewards/margins': '0.5408', 'logps/chosen': '-104.6', 'logps/rejected': '-151.8', 'epoch': '0.9854'}
# 100% 112/112 [09:07<00:00,  4.33s/it]Found 13 files to upload
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ░░░░░░░░░░░░░░░░░░░░  0 / 7 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  561kB · 1.12MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ████████░░░░░░░░░░░░  3 / 7 files  6.18MB · 4.15MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  32.6MB · 18.7MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  68.0MB · 34.3MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  105MB · 46.3MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  133MB · 48.9MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  134MB · 34.9MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  142MB · 29.5MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  178MB · 42.3MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  228MB · 59.2MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  291MB · 79.2MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  352MB · 92.1MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  403MB · 95.1MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  451MB · 95.2MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  473MB · 79.8MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  476MB · 57.8MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  480MB · 42.7MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  483MB · 32.2MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  488MB · 25.3MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  494MB · 21.0MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  501MB · 19.4MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  511MB · 19.6MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  524MB · 21.1MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ███████████░░░░░░░░░  4 / 7 files  524MB · 14.8MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ████████████████████  7 / 7 files  524MB · 10.6MB/s ✓
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ████████████████████  7 / 7 files  524MB · 7.41MB/s ✓
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ████████████████████  7 / 7 files  524MB · 7.41MB/s ✓
#   Committing  ████████████████████  13 / 13 ✓
# Found 4 files to upload
#   Preparing   ████████████████████  4 / 4 ✓
#   Uploading   ████████████████████  -
#   Committing  █████░░░░░░░░░░░░░░░  1 / 4
#   Preparing   ████████████████████  4 / 4 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████████████████  4 / 4 ✓
# {'train_runtime': '565.3', 'train_samples_per_second': '1.58', 'train_steps_per_second': '0.198', 'train_loss': '0.5647', 'entropy': '0.1871', 'num_tokens': '1.432e+06', 'logits/chosen': '1.375', 'logits/rejected': '3.764', 'mean_token_accuracy': '0.9666', 'rewards/chosen': '0.1776', 'rewards/rejected': '-0.2717', 'rewards/accuracies': '0.8462', 'rewards/margins': '0.4493', 'logps/chosen': '-120.7', 'logps/rejected': '-129.8', 'epoch': '1'}
# 100% 112/112 [09:23<00:00,  5.03s/it]
# COMPLETED: 20260814-114257--a2v2-playworld-dpo--s42--ef1e20
# final adapter sha256: sha256:cc23345fc5a46ddbf170af4697412ad71b5b247c681184265348c9499a3db351
# Found 16 files to upload
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ████████████████████  3 / 3 files ✓
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ████████████████████  3 / 3 files ✓
#   Committing  ██████████░░░░░░░░░░  8 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ████████████████████  3 / 3 files ✓
#   Committing  ████████████████████  16 / 16 ✓
# artifacts persisted: hf://model/m97j/aw-runs-a2/artifacts
# wandb:
# wandb: 🚀 View run a2v2-playworld-dpo at: https://wandb.ai/mmnkjiae-/axiom-world/runs/4pr7tjvr
# wandb: Find logs at: wandb/run-20260814_114305-4pr7tjvr/logs
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# run_id: 20260814-115239--b5-playworld-dpo--s42--4c45da
# Loading weights: 100% 399/399 [00:01<00:00, 343.20it/s]
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py:1348: UserWarning: Model has `tie_word_embeddings=True` and a tied layer is part of the adapter, but `ensure_weight_tying` is not set to True. This can lead to complications, for example when merging the adapter or converting your model to formats other than safetensors. Check the discussion here: https://github.com/huggingface/peft/issues/2777
#   warnings.warn(msg)
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Adding EOS to train dataset: 100% 1350/1350 [00:00<00:00, 67489.61 examples/s]
# Tokenizing train dataset: 100% 1350/1350 [00:01<00:00, 1092.98 examples/s]
# Dropping fully truncated examples from train dataset: 100% 1350/1350 [00:00<00:00, 105261.10 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: mmnkjiae (mmnkjiae-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.28.0
# wandb: Run data is saved locally in /content/axiom-world/wandb/run-20260814_115248-i97o1jh2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run b5-playworld-dpo
# wandb: ⭐️ View project at https://wandb.ai/mmnkjiae-/axiom-world
# wandb: 🚀 View run at https://wandb.ai/mmnkjiae-/axiom-world/runs/i97o1jh2
# {'loss': '0.6928', 'grad_norm': '6.503', 'learning_rate': '4.908e-07', 'entropy': '0.1123', 'num_tokens': '6.159e+04', 'logits/chosen': '5.668', 'logits/rejected': '5.843', 'mean_token_accuracy': '0.9608', 'rewards/chosen': '0.01405', 'rewards/rejected': '0.01306', 'rewards/accuracies': '0.3875', 'rewards/margins': '0.0009947', 'logps/chosen': '-19.29', 'logps/rejected': '-20.87', 'epoch': '0.05926'}
# {'loss': '0.693', 'grad_norm': '8.817', 'learning_rate': '4.601e-07', 'entropy': '0.112', 'num_tokens': '1.231e+05', 'logits/chosen': '5.601', 'logits/rejected': '5.721', 'mean_token_accuracy': '0.9622', 'rewards/chosen': '0.06941', 'rewards/rejected': '0.06762', 'rewards/accuracies': '0.525', 'rewards/margins': '0.001789', 'logps/chosen': '-18.57', 'logps/rejected': '-20.06', 'epoch': '0.1185'}
# {'loss': '0.6739', 'grad_norm': '6.68', 'learning_rate': '4.294e-07', 'entropy': '0.1201', 'num_tokens': '1.829e+05', 'logits/chosen': '5.319', 'logits/rejected': '5.413', 'mean_token_accuracy': '0.96', 'rewards/chosen': '0.1221', 'rewards/rejected': '0.08029', 'rewards/accuracies': '0.7625', 'rewards/margins': '0.04183', 'logps/chosen': '-17.69', 'logps/rejected': '-19.69', 'epoch': '0.1778'}
# {'loss': '0.6782', 'grad_norm': '6.829', 'learning_rate': '3.988e-07', 'entropy': '0.1122', 'num_tokens': '2.432e+05', 'logits/chosen': '5.3', 'logits/rejected': '5.373', 'mean_token_accuracy': '0.9604', 'rewards/chosen': '0.0716', 'rewards/rejected': '0.0331', 'rewards/accuracies': '0.6125', 'rewards/margins': '0.0385', 'logps/chosen': '-18.6', 'logps/rejected': '-20.39', 'epoch': '0.237'}
# {'loss': '0.6706', 'grad_norm': '8.364', 'learning_rate': '3.681e-07', 'entropy': '0.1098', 'num_tokens': '3.036e+05', 'logits/chosen': '5.068', 'logits/rejected': '5.273', 'mean_token_accuracy': '0.9598', 'rewards/chosen': '0.03476', 'rewards/rejected': '-0.02479', 'rewards/accuracies': '0.675', 'rewards/margins': '0.05954', 'logps/chosen': '-18.54', 'logps/rejected': '-21.22', 'epoch': '0.2963'}
# {'loss': '0.672', 'grad_norm': '9.663', 'learning_rate': '3.374e-07', 'entropy': '0.1066', 'num_tokens': '3.641e+05', 'logits/chosen': '5.042', 'logits/rejected': '5.144', 'mean_token_accuracy': '0.9625', 'rewards/chosen': '-0.003986', 'rewards/rejected': '-0.06728', 'rewards/accuracies': '0.5625', 'rewards/margins': '0.06329', 'logps/chosen': '-19.46', 'logps/rejected': '-21.87', 'epoch': '0.3556'}
# {'loss': '0.6488', 'grad_norm': '6.958', 'learning_rate': '3.067e-07', 'entropy': '0.1016', 'num_tokens': '4.254e+05', 'logits/chosen': '5.045', 'logits/rejected': '5.232', 'mean_token_accuracy': '0.9641', 'rewards/chosen': '-0.009101', 'rewards/rejected': '-0.1219', 'rewards/accuracies': '0.6625', 'rewards/margins': '0.1128', 'logps/chosen': '-19.31', 'logps/rejected': '-22.47', 'epoch': '0.4148'}
# {'loss': '0.6758', 'grad_norm': '7.643', 'learning_rate': '2.761e-07', 'entropy': '0.1037', 'num_tokens': '4.857e+05', 'logits/chosen': '4.837', 'logits/rejected': '5.111', 'mean_token_accuracy': '0.9603', 'rewards/chosen': '-0.06046', 'rewards/rejected': '-0.1194', 'rewards/accuracies': '0.6875', 'rewards/margins': '0.05892', 'logps/chosen': '-19.59', 'logps/rejected': '-21.71', 'epoch': '0.4741'}
# {'loss': '0.6655', 'grad_norm': '7.471', 'learning_rate': '2.454e-07', 'entropy': '0.1063', 'num_tokens': '5.458e+05', 'logits/chosen': '4.783', 'logits/rejected': '4.967', 'mean_token_accuracy': '0.9609', 'rewards/chosen': '-0.008018', 'rewards/rejected': '-0.09367', 'rewards/accuracies': '0.6625', 'rewards/margins': '0.08566', 'logps/chosen': '-19.2', 'logps/rejected': '-21.93', 'epoch': '0.5333'}
# {'loss': '0.6798', 'grad_norm': '7.187', 'learning_rate': '2.147e-07', 'entropy': '0.106', 'num_tokens': '6.061e+05', 'logits/chosen': '4.711', 'logits/rejected': '4.864', 'mean_token_accuracy': '0.965', 'rewards/chosen': '0.03254', 'rewards/rejected': '-0.02179', 'rewards/accuracies': '0.6375', 'rewards/margins': '0.05434', 'logps/chosen': '-18.67', 'logps/rejected': '-20.98', 'epoch': '0.5926'}
# {'loss': '0.6754', 'grad_norm': '8.265', 'learning_rate': '1.84e-07', 'entropy': '0.108', 'num_tokens': '6.659e+05', 'logits/chosen': '4.59', 'logits/rejected': '4.784', 'mean_token_accuracy': '0.9618', 'rewards/chosen': '0.02891', 'rewards/rejected': '-0.03392', 'rewards/accuracies': '0.625', 'rewards/margins': '0.06284', 'logps/chosen': '-18.76', 'logps/rejected': '-20.52', 'epoch': '0.6519'}
# {'loss': '0.6652', 'grad_norm': '11.02', 'learning_rate': '1.534e-07', 'entropy': '0.1035', 'num_tokens': '7.257e+05', 'logits/chosen': '4.621', 'logits/rejected': '4.789', 'mean_token_accuracy': '0.9615', 'rewards/chosen': '0.05461', 'rewards/rejected': '-0.02781', 'rewards/accuracies': '0.6', 'rewards/margins': '0.08242', 'logps/chosen': '-18.44', 'logps/rejected': '-20.61', 'epoch': '0.7111'}
# {'loss': '0.6855', 'grad_norm': '6.688', 'learning_rate': '1.227e-07', 'entropy': '0.1024', 'num_tokens': '7.855e+05', 'logits/chosen': '4.536', 'logits/rejected': '4.55', 'mean_token_accuracy': '0.9631', 'rewards/chosen': '0.03818', 'rewards/rejected': '0.005592', 'rewards/accuracies': '0.6', 'rewards/margins': '0.03258', 'logps/chosen': '-18.45', 'logps/rejected': '-19.85', 'epoch': '0.7704'}
# {'loss': '0.6553', 'grad_norm': '6.674', 'learning_rate': '9.202e-08', 'entropy': '0.1052', 'num_tokens': '8.456e+05', 'logits/chosen': '4.574', 'logits/rejected': '4.714', 'mean_token_accuracy': '0.963', 'rewards/chosen': '0.06484', 'rewards/rejected': '-0.03358', 'rewards/accuracies': '0.7375', 'rewards/margins': '0.09842', 'logps/chosen': '-18.27', 'logps/rejected': '-20.78', 'epoch': '0.8296'}
# {'loss': '0.6732', 'grad_norm': '6.441', 'learning_rate': '6.135e-08', 'entropy': '0.1013', 'num_tokens': '9.066e+05', 'logits/chosen': '4.664', 'logits/rejected': '4.756', 'mean_token_accuracy': '0.9646', 'rewards/chosen': '0.04339', 'rewards/rejected': '-0.01786', 'rewards/accuracies': '0.7', 'rewards/margins': '0.06125', 'logps/chosen': '-19.03', 'logps/rejected': '-20.95', 'epoch': '0.8889'}
# {'loss': '0.6423', 'grad_norm': '5.131', 'learning_rate': '3.067e-08', 'entropy': '0.1055', 'num_tokens': '9.672e+05', 'logits/chosen': '4.524', 'logits/rejected': '4.662', 'mean_token_accuracy': '0.965', 'rewards/chosen': '0.06061', 'rewards/rejected': '-0.06784', 'rewards/accuracies': '0.725', 'rewards/margins': '0.1285', 'logps/chosen': '-18.47', 'logps/rejected': '-21.75', 'epoch': '0.9481'}
# 100% 169/169 [07:50<00:00,  2.59s/it]Found 13 files to upload
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.80MB · 5.60MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  22.4MB · 15.7MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  59.5MB · 33.2MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  93.1MB · 43.4MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  129MB · 51.9MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  134MB · 39.0MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  206MB · 70.8MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  230MB · 63.8MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  342MB · 112MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  467MB · 153MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  530MB · 145MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  586MB · 135MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  775MB · 208MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.02GB · 295MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.21GB · 318MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.25GB · 247MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.27GB · 185MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.29GB · 140MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.36GB · 140MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.44GB · 146MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.51GB · 143MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.57GB · 139MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.63GB · 134MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.70GB · 133MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.77GB · 133MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.83GB · 132MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.90GB · 132MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  1.96GB · 131MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.03GB · 134MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.09GB · 131MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.17GB · 136MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.23GB · 133MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.29GB · 132MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.36GB · 131MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.43GB · 135MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.49GB · 131MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.56GB · 129MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.62GB · 132MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.70GB · 137MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.77GB · 139MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.84GB · 140MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.92GB · 144MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  2.99GB · 146MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.06GB · 144MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.14GB · 146MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.21GB · 145MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.28GB · 145MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.35GB · 143MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.43GB · 143MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.49GB · 138MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.55GB · 131MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.59GB · 121MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.62GB · 97.0MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.63GB · 79.3MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.65GB · 67.1MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.68GB · 62.6MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.70GB · 57.2MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.72GB · 50.9MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.75GB · 51.1MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.77GB · 50.0MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.79GB · 50.0MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████░░░░░░░░░░░░░░░  2 / 7 files  3.81GB · 41.4MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  3.82GB · 36.2MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  3.83GB · 33.8MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  3.85GB · 33.1MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  3.86GB · 31.1MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  3.88GB · 33.5MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  3.90GB · 36.3MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  3.92GB · 39.5MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  3.95GB · 42.8MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  3.98GB · 46.5MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.01GB · 52.3MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.05GB · 57.5MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.08GB · 61.5MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.12GB · 67.0MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.15GB · 63.9MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.17GB · 58.8MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.18GB · 48.0MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.19GB · 39.8MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.21GB · 36.2MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.22GB · 29.5MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.22GB · 20.9MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.22GB · 14.7MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.22GB · 10.3MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.22GB · 7.19MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.22GB · 5.04MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   █████████████████░░░  6 / 7 files  4.22GB · 3.53MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ████████████████████  7 / 7 files  4.22GB · 2.47MB/s ✓
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 13
#   Preparing   ████████████████████  13 / 13 ✓
#   Uploading   ████████████████████  7 / 7 files  4.22GB · 2.47MB/s ✓
#   Committing  ████████████████████  13 / 13 ✓
# Found 4 files to upload
#   Preparing   ████████████████████  4 / 4 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████████████████  4 / 4 ✓
# {'train_runtime': '540.4', 'train_samples_per_second': '2.498', 'train_steps_per_second': '0.313', 'train_loss': '0.6717', 'entropy': '0.1032', 'num_tokens': '1.02e+06', 'logits/chosen': '4.557', 'logits/rejected': '4.665', 'mean_token_accuracy': '0.9623', 'rewards/chosen': '0.0457', 'rewards/rejected': '-0.02651', 'rewards/accuracies': '0.6571', 'rewards/margins': '0.07221', 'logps/chosen': '-18.51', 'logps/rejected': '-20.38', 'epoch': '1'}
# 100% 169/169 [08:59<00:00,  3.19s/it]
# COMPLETED: 20260814-115239--b5-playworld-dpo--s42--4c45da
# final adapter sha256: sha256:34d0d22dfc04a97de2793eff12599113c48af5c05d7b28cbb3f3b604abc0c177
# Found 16 files to upload
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files  1.21MB · 2.41MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files  13.3MB · 8.92MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files  31.4MB · 17.1MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files  51.3MB · 23.9MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ██████░░░░░░░░░░░░░░  1 / 3 files  64.5MB · 24.7MB/s
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ████████████████████  3 / 3 files  64.9MB · 17.5MB/s ✓
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ████████████████████  3 / 3 files  64.9MB · 12.3MB/s ✓
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ████████████████████  3 / 3 files  64.9MB · 8.59MB/s ✓
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ████████████████████  3 / 3 files  64.9MB · 6.01MB/s ✓
#   Committing  █████░░░░░░░░░░░░░░░  4 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ████████████████████  3 / 3 files  64.9MB · 4.21MB/s ✓
#   Committing  █████░░░░░░░░░░░░░░░  4 / 16
#   Preparing   ████████████████████  16 / 16 ✓
#   Uploading   ████████████████████  3 / 3 files  64.9MB · 4.21MB/s ✓
#   Committing  ████████████████████  16 / 16 ✓
# artifacts persisted: hf://model/m97j/aw-runs-b5/artifacts
# wandb:
# wandb: 🚀 View run b5-playworld-dpo at: https://wandb.ai/mmnkjiae-/axiom-world/runs/i97o1jh2
# wandb: Find logs at: wandb/run-20260814_115248-i97o1jh2/logs

# %%
# @title c_eval — both DPO arms on the frozen suites
A2V2_RUN_ID = "20260814-114257--a2v2-playworld-dpo--s42--ef1e20"  # <- from b_train
B5_RUN_ID = "20260814-115239--b5-playworld-dpo--s42--4c45da"

out = !python scripts/fetch_run.py --repo m97j/aw-runs-a2 --run-id {A2V2_RUN_ID}
a2v2_dir = [l for l in out if l.startswith("ADAPTER_DIR=")][0].split("=", 1)[1]
out = !python scripts/fetch_run.py --repo m97j/aw-runs-b5 --run-id {B5_RUN_ID}
b5_dir = [l for l in out if l.startswith("ADAPTER_DIR=")][0].split("=", 1)[1]

# !python scripts/run_evaluation.py \
  --config configs/experiments/eval_playworld.yaml \
  --adapter-dir {a2v2_dir} \
  --max-new-tokens 1024 --batch-size 100 --hf-sync-repo m97j/aw-runs-a2
# !python scripts/run_evaluation.py \
  --config configs/experiments/eval_playworld.yaml \
  --adapter-dir {b5_dir} \
  --max-new-tokens 1024 --batch-size 100 --hf-sync-repo m97j/aw-runs-b5
# Out:
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Loading weights: 100% 399/399 [00:01<00:00, 339.00it/s]
# generate(batched): 100% 3/3 [06:39<00:00, 133.31s/it]
# eval_adversarial: pass_rate={'mean': 0.6433, 'ci95': [0.59, 0.6967]}
# generate(batched): 100% 3/3 [06:58<00:00, 139.63s/it]
# eval_comp_ood: pass_rate={'mean': 0.1433, 'ci95': [0.1033, 0.1833]}
# generate(batched): 100% 3/3 [06:56<00:00, 138.76s/it]
# eval_id: pass_rate={'mean': 0.1867, 'ci95': [0.1433, 0.2333]}
# generate(batched): 100% 3/3 [06:59<00:00, 139.97s/it]
# eval_rule_ood: pass_rate={'mean': 0.1967, 'ci95': [0.1533, 0.2433]}
# generate(batched): 100% 3/3 [06:58<00:00, 139.37s/it]
# eval_template_ood: pass_rate={'mean': 0.21, 'ci95': [0.1667, 0.2567]}
# outputs truncated at max_new_tokens: 1490
# eval run: 20260814-120733--eval-playworld--s42--61d7cd
# Found 8 files to upload
#   Preparing   ████████████████████  8 / 8 ✓
#   Uploading   ████████████████████  -
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 8
#   Preparing   ████████████████████  8 / 8 ✓
#   Uploading   ████████████████████  -
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 8
#   Preparing   ████████████████████  8 / 8 ✓
#   Uploading   ████████████████████  -
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 8
#   Preparing   ████████████████████  8 / 8 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████████████████  8 / 8 ✓
# eval artifacts synced -> hf://model/m97j/aw-runs-a2/runs/20260814-120733--eval-playworld--s42--61d7cd
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Loading weights: 100% 399/399 [00:01<00:00, 338.52it/s]
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py:1348: UserWarning: Model has `tie_word_embeddings=True` and a tied layer is part of the adapter, but `ensure_weight_tying` is not set to True. This can lead to complications, for example when merging the adapter or converting your model to formats other than safetensors. Check the discussion here: https://github.com/huggingface/peft/issues/2777
#   warnings.warn(msg)
# generate(batched): 100% 3/3 [00:35<00:00, 11.68s/it]
# eval_adversarial: pass_rate={'mean': 0.8167, 'ci95': [0.77, 0.86]}
# generate(batched): 100% 3/3 [00:58<00:00, 19.35s/it]
# eval_comp_ood: pass_rate={'mean': 0.2933, 'ci95': [0.2433, 0.3467]}
# generate(batched): 100% 3/3 [00:49<00:00, 16.59s/it]
# eval_id: pass_rate={'mean': 0.38, 'ci95': [0.3233, 0.4333]}
# generate(batched): 100% 3/3 [00:57<00:00, 19.01s/it]
# eval_rule_ood: pass_rate={'mean': 0.3067, 'ci95': [0.2567, 0.36]}
# generate(batched): 100% 3/3 [00:57<00:00, 19.32s/it]
# eval_template_ood: pass_rate={'mean': 0.3367, 'ci95': [0.2833, 0.39]}
# outputs truncated at max_new_tokens: 0
# eval run: 20260814-124224--eval-playworld--s42--f77cd8
# Found 8 files to upload
#   Preparing   ████████████████████  8 / 8 ✓
#   Uploading   ████████████████████  -
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 8
#   Preparing   ████████████████████  8 / 8 ✓
#   Uploading   ████████████████████  -
#   Committing  ░░░░░░░░░░░░░░░░░░░░  0 / 8
#   Preparing   ████████████████████  8 / 8 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████████████████  8 / 8 ✓
# eval artifacts synced -> hf://model/m97j/aw-runs-b5/runs/20260814-124224--eval-playworld--s42--f77cd8

# %%
# @title x09i_run_audit — both DPO evals (CPU)
A2V2_EVAL = "20260814-120733--eval-playworld--s42--61d7cd"  # <- eval run ids from c_eval
B5_EVAL = "20260814-124224--eval-playworld--s42--f77cd8"

# !python scripts/fetch_run.py --repo m97j/aw-runs-a2 --run-id {A2V2_EVAL} --kind eval
# !python scripts/fetch_run.py --repo m97j/aw-runs-b5 --run-id {B5_EVAL} --kind eval
# !python scripts/x09_termination_audit.py \
  --run-dirs runs/{A2V2_EVAL} runs/{B5_EVAL} --out runs/x09_run_audit_phase2dpo.json
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 8 files:   0% 0/8 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/1.62M [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/1.63M [00:00<?, ?B/s]
# Downloading bytes:   0% 3.50k/1.63M [00:00<02:08, 12.7kB/s]
# Reconstructing (incomplete total...):   0% 3.50k/3.48M [00:00<04:34, 12.7kB/s]
# Reconstructing (incomplete total...):   0% 3.50k/5.32M [00:00<06:59, 12.7kB/s]
# Reconstructing (incomplete total...):   0% 3.50k/7.22M [00:00<09:29, 12.7kB/s]
# Reconstructing (incomplete total...):   0% 3.50k/7.22M [00:00<09:29, 12.7kB/s]
# Reconstructing (incomplete total...):  74% 5.32M/7.22M [00:00<02:29, 12.7kB/s]
#
# Fetching 8 files:  12% 1/8 [00:00<00:02,  3.09it/s]
# Reconstructing (incomplete total...):  59% 5.32M/9.04M [00:00<04:53, 12.7kB/s]
# Fetching 8 files: 100% 8/8 [00:00<00:00, 20.38it/s]
# Download complete: 100% 9.04M/9.04M [00:00<00:00, 28.9MB/s]
# Reconstruction complete: 100% 9.04M/9.04M [00:00<00:00, 28.9MB/s]             eval run materialized: 5 suite files, freeze_fingerprint=sha256:3cdcbc30c99e492c...
# RUN_DIR=runs/20260814-120733--eval-playworld--s42--61d7cd
# Download complete: 100% 9.04M/9.04M [00:00<00:00, 22.2MB/s]
# Reconstruction complete: 100% 9.04M/9.04M [00:00<00:00, 22.2MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 8 files:   0% 0/8 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/389k [00:00<?, ?B/s]
# Downloading bytes: 100% 389k/389k [00:00<00:00, 1.50MB/s]
# Reconstructing (incomplete total...):  46% 389k/841k [00:00<00:00, 1.50MB/s]
# Reconstructing (incomplete total...):  46% 389k/844k [00:00<00:00, 1.50MB/s]
# Reconstructing (incomplete total...):  30% 393k/1.30M [00:00<00:00, 1.50MB/s]
# Reconstructing (incomplete total...):  30% 393k/1.30M [00:00<00:00, 1.50MB/s]
#
# Fetching 8 files:  12% 1/8 [00:00<00:01,  3.63it/s]
# Reconstructing (incomplete total...):  22% 393k/1.75M [00:00<00:00, 1.50MB/s]
# Reconstructing (incomplete total...):  39% 845k/2.19M [00:00<00:00, 1.50MB/s]
# Reconstructing (incomplete total...): 100% 2.19M/2.19M [00:00<00:00, 1.50MB/s]
# Downloading bytes: 100% 2.19M/2.19M [00:00<00:00, 5.87MB/s]
#
# Fetching 8 files: 100% 8/8 [00:00<00:00, 18.75it/s]
# Download complete: 100% 2.19M/2.19M [00:00<00:00, 5.87MB/s]
# Reconstruction complete: 100% 2.19M/2.19M [00:00<00:00, 5.87MB/s]             eval run materialized: 5 suite files, freeze_fingerprint=sha256:3cdcbc30c99e492c...
# RUN_DIR=runs/20260814-124224--eval-playworld--s42--f77cd8
# Download complete: 100% 2.19M/2.19M [00:00<00:00, 4.93MB/s]
# Reconstruction complete: 100% 2.19M/2.19M [00:00<00:00, 4.93MB/s]
# {
#   "run_audit": [
#     {
#       "run_dir": "runs/20260814-120733--eval-playworld--s42--61d7cd",
#       "trace_rows": 1500,
#       "duplicate_rows_dropped": 1500,
#       "suites": {
#         "eval_adversarial": 300,
#         "eval_comp_ood": 300,
#         "eval_id": 300,
#         "eval_rule_ood": 300,
#         "eval_template_ood": 300
#       },
#       "summary_found": true,
#       "truncated_outputs": 1490,
#       "truncation_rate": 0.9933,
#       "max_new_tokens": 1024,
#       "conditioning": {
#         "few_shot_exemplars_path": null,
#         "few_shot_k": 0,
#         "opener_seed": "<think>\n\n</think>\n\n"
#       },
#       "verdict_reason_codes": {
#         "required_component_failed": 929,
#         "weighted_aggregation": 414,
#         "gate_failed:malformed_json": 153,
#         "gate_failed:action_schema_invalid": 4
#       },
#       "empty_predictions": 0,
#       "runaway_tail_repetition": 1365,
#       "runaway_rate": 0.91,
#       "prediction_chars": {
#         "mean": 2473.8,
#         "max": 11530
#       }
#     },
#     {
#       "run_dir": "runs/20260814-124224--eval-playworld--s42--f77cd8",
#       "trace_rows": 1500,
#       "duplicate_rows_dropped": 1500,
#       "suites": {
#         "eval_adversarial": 300,
#         "eval_comp_ood": 300,
#         "eval_id": 300,
#         "eval_rule_ood": 300,
#         "eval_template_ood": 300
#       },
#       "summary_found": true,
#       "truncated_outputs": 0,
#       "truncation_rate": 0.0,
#       "max_new_tokens": 1024,
#       "conditioning": {
#         "few_shot_exemplars_path": null,
#         "few_shot_k": 0,
#         "opener_seed": "<think>\n\n</think>\n\n"
#       },
#       "verdict_reason_codes": {
#         "required_component_failed": 860,
#         "weighted_aggregation": 640
#       },
#       "empty_predictions": 0,
#       "runaway_tail_repetition": 0,
#       "runaway_rate": 0.0,
#       "prediction_chars": {
#         "mean": 262.8,
#         "max": 560
#       }
#     }
#   ]
# }

# %%
# @title f_analysis — Phase-2 comparisons
B4V2_EVAL = "20260814-032546--eval-playworld--s42--7308ee"
A1V2_EVAL = "20260814-025057--eval-playworld--s42--a27857"

# !python scripts/fetch_run.py --repo m97j/aw-runs-b4 --run-id {B4V2_EVAL} --kind eval
# !python scripts/fetch_run.py --repo m97j/aw-runs-a1 --run-id {A1V2_EVAL} --kind eval

# DPO gain per track
# !python scripts/run_analysis.py \
  --run-a runs/{B5_EVAL} --label-a b5-dpo --run-b runs/{B4V2_EVAL} --label-b b4v2-sft \
  --output runs/{B5_EVAL}/analysis_b5_vs_b4v2.json --hf-sync-repo m97j/aw-runs-b5
# !python scripts/run_analysis.py \
  --run-a runs/{A2V2_EVAL} --label-a a2v2-dpo --run-b runs/{A1V2_EVAL} --label-b a1v2-sft \
  --output runs/{A2V2_EVAL}/analysis_a2v2_vs_a1v2.json --hf-sync-repo m97j/aw-runs-a2

# Phase-2 headline: two-stage vs direct after identical DPO
# !python scripts/run_analysis.py \
  --run-a runs/{B5_EVAL} --label-a b5-two-stage-dpo --run-b runs/{A2V2_EVAL} --label-b a2v2-direct-dpo \
  --output runs/{B5_EVAL}/analysis_b5_vs_a2v2.json --hf-sync-repo m97j/aw-runs-b5
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 19 files:   0% 0/19 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/6.12k [00:00<?, ?B/s]
# Downloading bytes: 100% 6.12k/6.12k [00:00<00:00, 24.7kB/s]
# Reconstructing (incomplete total...):   1% 6.12k/440k [00:00<00:17, 24.7kB/s]
# Reconstructing (incomplete total...):   1% 6.12k/886k [00:00<00:35, 24.7kB/s]
# Reconstructing (incomplete total...):  99% 886k/892k [00:00<00:00, 24.7kB/s]
#
# Fetching 19 files:   5% 1/19 [00:00<00:05,  3.43it/s]
# Reconstructing (incomplete total...):  67% 892k/1.34M [00:00<00:18, 24.7kB/s]
# Reconstructing (incomplete total...):  78% 1.34M/1.73M [00:00<00:15, 24.7kB/s]
# Reconstructing (incomplete total...):  78% 1.34M/1.73M [00:00<00:15, 24.7kB/s]
# Downloading bytes:  78% 1.34M/1.73M [00:00<00:00, 3.91MB/s]
#
# Fetching 19 files:  16% 3/19 [00:00<00:01,  8.28it/s]
# Reconstructing (incomplete total...):  79% 1.73M/2.18M [00:00<00:00, 3.91MB/s]
# Reconstructing (incomplete total...): 100% 2.18M/2.18M [00:00<00:00, 3.91MB/s]
# Reconstructing (incomplete total...): 100% 2.18M/2.18M [00:00<00:00, 3.91MB/s]
# Downloading bytes: 100% 2.18M/2.18M [00:00<00:00, 5.03MB/s]
# Reconstructing (incomplete total...): 100% 2.18M/2.18M [00:00<00:00, 5.04MB/s]
#
# Fetching 19 files:  53% 10/19 [00:00<00:00, 25.92it/s]
# Reconstructing (incomplete total...):  85% 2.18M/2.57M [00:00<00:00, 5.04MB/s]
# Reconstructing (incomplete total...):  85% 2.57M/3.02M [00:00<00:00, 5.04MB/s]
# Reconstructing (incomplete total...):  87% 3.02M/3.45M [00:00<00:00, 5.04MB/s]
# Reconstructing (incomplete total...):  77% 3.02M/3.90M [00:00<00:00, 5.04MB/s]
# Downloading bytes:  89% 3.45M/3.90M [00:00<00:00, 6.42MB/s]
#
# Fetching 19 files:  74% 14/19 [00:00<00:00, 26.71it/s]
# Reconstructing (incomplete total...):  79% 3.45M/4.35M [00:00<00:00, 6.42MB/s]
# Reconstructing (incomplete total...): 100% 4.35M/4.35M [00:00<00:00, 6.42MB/s]
# Reconstructing (incomplete total...): 100% 4.35M/4.35M [00:00<00:00, 6.42MB/s]
# Downloading bytes: 100% 4.35M/4.35M [00:00<00:00, 7.10MB/s]
# Reconstructing (incomplete total...): 100% 4.35M/4.35M [00:00<00:00, 7.10MB/s]
#
# Fetching 19 files: 100% 19/19 [00:00<00:00, 24.47it/s]
# Download complete: 100% 4.35M/4.35M [00:00<00:00, 7.10MB/s]
# Reconstruction complete: 100% 4.35M/4.35M [00:00<00:00, 7.10MB/s]             eval run materialized: 5 suite files, freeze_fingerprint=sha256:3cdcbc30c99e492c...
# RUN_DIR=runs/20260814-032546--eval-playworld--s42--7308ee
# Download complete: 100% 4.35M/4.35M [00:00<00:00, 5.49MB/s]
# Reconstruction complete: 100% 4.35M/4.35M [00:00<00:00, 5.49MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 18 files:   0% 0/18 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/3.64k [00:00<?, ?B/s]
# Downloading bytes: 100% 3.64k/3.64k [00:00<00:00, 14.6kB/s]
# Reconstructing (incomplete total...):  37% 3.64k/9.74k [00:00<00:00, 14.7kB/s]
#
# Fetching 18 files:   6% 1/18 [00:00<00:04,  3.73it/s]
# Reconstructing (incomplete total...):  94% 9.74k/10.3k [00:00<00:00, 14.7kB/s]
# Reconstructing (incomplete total...):   0% 10.3k/2.07M [00:00<02:20, 14.7kB/s]
# Reconstructing (incomplete total...):   0% 10.3k/4.15M [00:00<04:42, 14.7kB/s]
# Reconstructing (incomplete total...):   0% 10.3k/6.05M [00:00<06:51, 14.7kB/s]
# Downloading bytes: 100% 6.05M/6.05M [00:00<00:00, 20.4MB/s]
# Reconstructing (incomplete total...):  79% 6.05M/7.63M [00:00<00:00, 20.4MB/s]
# Reconstructing (incomplete total...):  64% 6.05M/9.46M [00:00<00:00, 20.4MB/s]
#
# Fetching 18 files:  17% 3/18 [00:00<00:02,  7.27it/s]
# Reconstructing (incomplete total...): 100% 9.46M/9.46M [00:00<00:00, 20.4MB/s]
# Downloading bytes: 100% 9.46M/9.46M [00:00<00:00, 23.0MB/s]
# Reconstructing (incomplete total...): 100% 9.46M/9.46M [00:00<00:00, 23.0MB/s]
# Reconstructing (incomplete total...):  86% 9.46M/11.0M [00:00<00:00, 23.0MB/s]
# Reconstructing (incomplete total...):  72% 9.46M/13.1M [00:00<00:00, 23.0MB/s]
# Reconstructing (incomplete total...):  63% 9.46M/14.9M [00:00<00:00, 23.0MB/s]
# Downloading bytes:  88% 13.1M/14.9M [00:00<00:00, 25.8MB/s]
# Reconstructing (incomplete total...):  77% 13.1M/17.0M [00:00<00:00, 25.8MB/s]
#
# Fetching 18 files:  61% 11/18 [00:00<00:00, 23.65it/s]
# Reconstructing (incomplete total...):  90% 17.0M/18.9M [00:00<00:00, 25.8MB/s]
# Reconstructing (incomplete total...):  90% 17.0M/18.9M [00:00<00:00, 25.8MB/s]
# Reconstructing (incomplete total...): 100% 18.9M/18.9M [00:00<00:00, 25.8MB/s]
# Downloading bytes: 100% 18.9M/18.9M [00:00<00:00, 32.5MB/s]
#
# Fetching 18 files:  94% 17/18 [00:00<00:00, 30.83it/s]
# Fetching 18 files: 100% 18/18 [00:00<00:00, 21.96it/s]
# Download complete: 100% 18.9M/18.9M [00:00<00:00, 32.5MB/s]
# Reconstruction complete: 100% 18.9M/18.9M [00:00<00:00, 32.5MB/s]             eval run materialized: 5 suite files, freeze_fingerprint=sha256:3cdcbc30c99e492c...
# RUN_DIR=runs/20260814-025057--eval-playworld--s42--a27857
# Download complete: 100% 18.9M/18.9M [00:00<00:00, 22.6MB/s]
# Reconstruction complete: 100% 18.9M/18.9M [00:00<00:00, 22.6MB/s]
# ==============================================================================
# suite                metric          b5-dpo   b4v2-sft    delta             95% CI    p-perm sig
# ------------------------------------------------------------------------------
# eval_id              pass_rate       0.3800     0.3933  -0.0133    [-0.050,+0.023]   0.58684 no
# eval_id              mean_score      0.5990     0.5925  +0.0064    [-0.023,+0.036]   0.67253 no
# eval_template_ood    pass_rate       0.3367     0.3500  -0.0133    [-0.057,+0.030]   0.64024 no
# eval_template_ood    mean_score      0.5854     0.5586  +0.0267    [-0.010,+0.065]   0.16998 no
# eval_comp_ood        pass_rate       0.2933     0.3033  -0.0100    [-0.047,+0.023]   0.71313 no
# eval_comp_ood        mean_score      0.5674     0.5464  +0.0210    [-0.014,+0.057]   0.25457 no
# eval_rule_ood        pass_rate       0.3067     0.2967  +0.0100    [-0.027,+0.050]   0.72613 no
# eval_rule_ood        mean_score      0.5366     0.5126  +0.0240    [-0.010,+0.059]   0.17158 no
# eval_adversarial     pass_rate       0.8167     0.8533  -0.0367    [-0.070,-0.003]   0.04689 YES
# eval_adversarial     mean_score      0.9426     0.9505  -0.0079    [-0.023,+0.007]   0.33287 no
# ==============================================================================
# analysis summary -> runs/20260814-124224--eval-playworld--s42--f77cd8/analysis_b5_vs_b4v2.json
# Found 18 files to upload
#   Preparing   ████████████████████  18 / 18 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████░░░░░░░░░░░░  8 / 18
#   Preparing   ████████████████████  18 / 18 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████░░░░░░░░░░░░  8 / 18
#   Preparing   ████████████████████  18 / 18 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████████████████  18 / 18 ✓
# analysis artifacts synced -> hf://model/m97j/aw-runs-b5/runs/20260814-124224--eval-playworld--s42--f77cd8
# ==============================================================================
# suite                metric        a2v2-dpo   a1v2-sft    delta             95% CI    p-perm sig
# ------------------------------------------------------------------------------
# eval_id              pass_rate       0.1867     0.1667  +0.0200    [-0.010,+0.050]   0.26317 no
# eval_id              mean_score      0.4487     0.4457  +0.0031    [-0.016,+0.023]   0.75792 no
# eval_template_ood    pass_rate       0.2100     0.1900  +0.0200    [-0.003,+0.047]   0.17938 no
# eval_template_ood    mean_score      0.4625     0.4184  +0.0441    [+0.022,+0.068]   0.00020 YES
# eval_comp_ood        pass_rate       0.1433     0.1367  +0.0067    [-0.020,+0.033]   0.80572 no
# eval_comp_ood        mean_score      0.4015     0.3760  +0.0255    [+0.004,+0.048]   0.02280 YES
# eval_rule_ood        pass_rate       0.1967     0.1833  +0.0133    [-0.020,+0.047]   0.55134 no
# eval_rule_ood        mean_score      0.3912     0.3677  +0.0235    [-0.006,+0.053]   0.10929 no
# eval_adversarial     pass_rate       0.6433     0.5900  +0.0533    [+0.013,+0.093]   0.01350 YES
# eval_adversarial     mean_score      0.7306     0.6566  +0.0740    [+0.036,+0.113]   0.00020 YES
# ==============================================================================
# analysis summary -> runs/20260814-120733--eval-playworld--s42--61d7cd/analysis_a2v2_vs_a1v2.json
# Found 18 files to upload
#   Preparing   ████████████████████  18 / 18 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████░░░░░░░░░░░░  8 / 18
#   Preparing   ████████████████████  18 / 18 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████░░░░░░░░░░░░  8 / 18
#   Preparing   ████████████████████  18 / 18 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████████████████  18 / 18 ✓
# analysis artifacts synced -> hf://model/m97j/aw-runs-a2/runs/20260814-120733--eval-playworld--s42--61d7cd
# ==============================================================================
# suite                metric      b5-two-stage-dpo a2v2-direct-dpo    delta             95% CI    p-perm sig
# ------------------------------------------------------------------------------
# eval_id              pass_rate       0.3800     0.1867  +0.1933    [+0.137,+0.250]   0.00010 YES
# eval_id              mean_score      0.5990     0.4487  +0.1502    [+0.108,+0.194]   0.00010 YES
# eval_template_ood    pass_rate       0.3367     0.2100  +0.1267    [+0.077,+0.177]   0.00010 YES
# eval_template_ood    mean_score      0.5854     0.4625  +0.1229    [+0.081,+0.166]   0.00010 YES
# eval_comp_ood        pass_rate       0.2933     0.1433  +0.1500    [+0.100,+0.200]   0.00010 YES
# eval_comp_ood        mean_score      0.5674     0.4015  +0.1659    [+0.123,+0.209]   0.00010 YES
# eval_rule_ood        pass_rate       0.3067     0.1967  +0.1100    [+0.060,+0.163]   0.00020 YES
# eval_rule_ood        mean_score      0.5366     0.3912  +0.1455    [+0.100,+0.192]   0.00010 YES
# eval_adversarial     pass_rate       0.8167     0.6433  +0.1733    [+0.113,+0.237]   0.00010 YES
# eval_adversarial     mean_score      0.9426     0.7306  +0.2120    [+0.167,+0.259]   0.00010 YES
# ==============================================================================
# analysis summary -> runs/20260814-124224--eval-playworld--s42--f77cd8/analysis_b5_vs_a2v2.json
# Found 19 files to upload
#   Preparing   ████████████████████  19 / 19 ✓
#   Uploading   ████████████████████  -
#   Committing  ████████████████████  19 / 19 ✓
# analysis artifacts synced -> hf://model/m97j/aw-runs-b5/runs/20260814-124224--eval-playworld--s42--f77cd8

# %% [markdown]
# ## Stage checklist — CLOSED 2026-08-14
# - [x] Mining manifests: b4v2 1350 pairs (.675) vs a1v2 893 (.447) — recorded
# - [x] a2v2 ef1e20 / b5 4c45da lineage verified (parents 70c2ecb9 / d4fcacdd)
# - [x] Evals 61d7cd / f77cd8; freeze 3cdcbc30; x09: b5 0.0/0.0, a2v2 .993/.91
# - [x] B5 vs B4v2: ~null (adversarial pass −.037 p=.047 isolated) — DPO no gain after two-stage
# - [x] A2v2 vs A1v2: modest sig mean_score gains, pass_rate mostly n.s.
# - [x] **Phase-2 headline: B5 ≫ A2v2, 10/10 p≤.0002**
# - [x] §6 Phase-2 champion = **B4v2** (proxy tie → rule-OOD tie → GPU-hours)
# - [x] Next: B6 GRPO from B4v2 (aw_09_b6)
